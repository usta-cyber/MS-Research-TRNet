# %% [markdown]
# ## Dataset Overview
# HAM10000 ("Human Against Machine with 10000 training images") dataset - a large collection of multi-source dermatoscopic images of pigmented lesions
#
# The dermatoscopic images are collected from different populations, acquired and stored by different modalities. The final dataset consists of 10015 dermatoscopic images.
#
# It has 7 different classes of skin cancer which are listed below :
# - Melanocytic nevi
# - Melanoma
# - Benign keratosis-like lesions
# - Basal cell carcinoma
# - Actinic keratoses
# - Vascular lesions
# - Dermatofibroma

# %% [markdown]
# ## Importing libraries

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from imblearn.over_sampling import RandomOverSampler 
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score,KFold

import os, cv2
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPool2D, Activation, BatchNormalization
from sklearn.metrics import classification_report, accuracy_score

# %% [markdown]
# ## Reading the Data

# %%
data = pd.read_csv('/kaggle/input/skin-cancer-mnist-ham10000/hmnist_28_28_RGB.csv')
data.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 0        197        154        185        202  ...        173        124
# 1        123         93        126        158  ...         60         39
# 2        201        142        160        206  ...        167        129
# 3        143        103        119        171  ...         44         26
# 4        215        162        191        225  ...        209        166
#
#    pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# 0        138        183        147        166        185        154
# 1         55         25         14         28         25         14
# 2        143        159        124        142        136        104
# 3         36         25         12         17         25         12
# 4        185        172        135        149        109         78
#
#    pixel2351  label
# 0        177      2
# 1         27      2
# 2        117      2
# 3         15      2
# 4         92      2
#
# [5 rows x 2353 columns]

# %%
f , ax = plt.subplots(2,5)
f.set_size_inches(15, 15)
k = 0
y1 = data['label']
x1 = data.drop(columns = ['label'])
x1= np.array(x1).reshape(-1,28,28,3)
for i in range(2):
    for j in range(5):
        ax[i,j].imshow(x1[k].reshape(28,28,3))
#         ax[i, j].set_title(f"Image {Y_train[4]}")
        k = k + 1
    plt.tight_layout()

# %% [markdown]
# ## Data Preprocessing
# ## Data Cleaning

# %%
data['label'].unique()
y = data['label']
x = data.drop(columns = ['label'])
data.isnull().sum().sum() #no null values present
# Out:
# 0

# %%
meta_data = pd.read_csv('/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_metadata.csv')
meta_data.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
meta_data['dx'].unique()
# Out:
# array(['bkl', 'nv', 'df', 'mel', 'vasc', 'bcc', 'akiec'], dtype=object)

# %%
data.isnull().sum().sum() #no null values present
meta_data.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %% [markdown]
# ## Exploratory Data Analysis

# %%
sns.countplot(x = 'dx', data = meta_data)
plt.xlabel('Disease(Classes)', size=12)
plt.ylabel('Frequency', size=12)
plt.title('Frequency Distribution of Classes')
# Out:
# Text(0.5, 1.0, 'Frequency Distribution of Classes')

# %%
sns.set_style('whitegrid')
colors = ['#87ace8','#e3784d', 'green']
fig,axes = plt.subplots(figsize=(8,8))

ax = sns.countplot(x='sex',data=meta_data, palette = 'Paired')
for container in ax.containers:
    ax.bar_label(container)
plt.title('Gender-wise Distribution',fontweight='bold', fontsize=12)
plt.xticks(rotation=45)
plt.xticks(fontweight='bold', fontsize=12)
plt.yticks(fontweight='bold', fontsize=12)
plt.show()

# %%
sns.set_style('whitegrid')
fig,axes = plt.subplots(figsize=(8,6))
ax = sns.countplot(x='dx',data=meta_data, order = meta_data['dx'].value_counts().index, palette = 'Paired')
for container in ax.containers:
    ax.bar_label(container)
plt.title('Skin Disease class distribution',fontweight='bold',fontsize=14)
plt.xticks(rotation=45)
plt.ylim(0, 8000)
plt.xticks(fontweight='bold', fontsize=12)
plt.yticks(fontweight='bold', fontsize=12)
plt.ylabel("Count",fontweight='bold', fontsize=14)
plt.xlabel("Disease Class", fontweight='bold', fontsize=14)
plt.show()

# %%
classes = {2:'bkl', 4:'nv', 3:'df', 6:'mel', 5:'vasc', 1:'bcc', 0:'akiec'}

classes_labels=[]
for key in classes.keys():
    classes_labels.append(key)
print(classes_labels)
# Out:
# [2, 4, 3, 6, 5, 1, 0]

# %%
sns.set_style('whitegrid')
fig,axes = plt.subplots(figsize=(12,8))
ax = sns.countplot(x='dx',hue='sex', data=meta_data, order = meta_data['dx'].value_counts().index, palette = 'Paired')
for container in ax.containers:
    ax.bar_label(container)
plt.title('Cell Types Frequencies',fontweight='bold', fontsize=14)
plt.xticks(rotation=45)
plt.xticks(fontweight='bold', fontsize=12)
plt.yticks(fontweight='bold', fontsize=12)
plt.ylabel("Count",fontweight='bold', fontsize=14)
plt.xlabel("Gender Wise Disease Class", fontweight='bold', fontsize=14)
plt.show()

# %%
sns.set_style('whitegrid')
fig,axes = plt.subplots(figsize=(12,8))
ax = sns.countplot(x='localization',data=meta_data, order = meta_data['localization'].value_counts().index, palette = 'crest')
for container in ax.containers:
    ax.bar_label(container)
plt.title('Localization Area Frequencies',fontweight='bold', fontsize=14)
plt.xticks(rotation=45)
plt.xticks(fontweight='bold', fontsize=12)
plt.yticks(fontweight='bold', fontsize=12)
plt.ylabel("Count",fontweight='bold', fontsize=14)
plt.xlabel("localization", fontweight='bold', fontsize=14)
plt.show()

# %%
sns.set_style('whitegrid')
fig,axes = plt.subplots(figsize=(12,8))
ax = sns.histplot(data=meta_data, x='age')
plt.title('Age Histogram',fontweight='bold', fontsize=14)
plt.xticks(fontweight='bold', fontsize=12)
plt.yticks(fontweight='bold', fontsize=12)
plt.ylabel("Count",fontweight='bold', fontsize=14)
plt.xlabel("Age", fontweight='bold', fontsize=14)
plt.show()

# %%
sns.set_style('whitegrid')
fig,axes = plt.subplots(figsize=(12,8))
ax = sns.histplot(data=meta_data, x='age',hue='sex',multiple='stack')
plt.title('Age Histogram Gender Wise',fontweight='bold', fontsize=14)
plt.xticks(fontweight='bold', fontsize=12)
plt.yticks(fontweight='bold', fontsize=12)
plt.ylabel("Count",fontweight='bold', fontsize=14)
plt.xlabel("Age", fontweight='bold', fontsize=14)
plt.show()

# %%
# Splitting Data
X_train, X_test, Y_train, Y_test = train_test_split(x,y, test_size=0.2, random_state=1)
print(X_train.shape,Y_train.shape)
print(X_test.shape , Y_test.shape)
# Out:
# (8012, 2352) (8012,)
# (2003, 2352) (2003,)

# %%
print(x.shape,y.shape)
print(X_train.shape,Y_train.shape)
print(X_test.shape,Y_test.shape)

# # To overcome class imbalace
oversample = RandomOverSampler()
Data,Label  = oversample.fit_resample(X_train,Y_train)
print(Data.shape,Label.shape)
# Out:
# (10015, 2352) (10015,)
# (8012, 2352) (8012,)
# (2003, 2352) (2003,)
# (37646, 2352) (37646,)

# %%
# reshaping the data so that it can be taken by convolution neural network(without disturbing the no. of samples)
Data= np.array(Data).reshape(-1,28,28,3)
print('Shape of X :',Data.shape)
print('Shape of y :',Label.shape)
# Out:
# Shape of X : (37646, 28, 28, 3)
# Shape of y : (37646,)

# %%
X_test= np.array(X_test).reshape(-1,28,28,3)

# %%
print(Label)
# Out:
# 0        2
# 1        4
# 2        4
# 3        6
# 4        5
#         ..
# 37641    6
# 37642    6
# 37643    6
# 37644    6
# 37645    6
# Name: label, Length: 37646, dtype: int64

# %%
newLabel = []

for i in range(len(Label)):
    for key in classes.keys():
        if Label[i] == key:
            newLabel.append(classes[key])

# %%
sns.set_style('whitegrid')
fig,axes = plt.subplots(figsize=(8,8))
ax = sns.countplot(x=newLabel,data=data,width=0.5)
for container in ax.containers:
    ax.bar_label(container, fontweight='bold', fontsize=11)
plt.title('Balance Data using Over Sampling', fontweight='bold', fontsize=14)
plt.ylim(0, 8000)
plt.xticks(fontweight='bold', fontsize=12)
plt.yticks(fontweight='bold', fontsize=12)
plt.ylabel("Count",fontweight='bold', fontsize=14)
plt.xlabel("Disease Class", fontweight='bold', fontsize=14)

plt.grid(linewidth=0.8)
plt.show()

# %%
Data = np.array(Data).reshape(-1,28,28,3)
print('Shape of X :',Data.shape)
print('Shape of y :',Label.shape)
# Out:
# Shape of X : (37646, 28, 28, 3)
# Shape of y : (37646,)

# %%
# Splitting Data
# X_train, X_test, Y_train, Y_test = train_test_split(Data,Label, test_size=0.2, random_state=1)
# print(X_train.shape,Y_train.shape)
# print(X_test.shape , Y_test.shape)
# Out:
# (37548, 28, 28, 3) (37548,)
# (9387, 28, 28, 3) (9387,)

# %%
# index = range(len(X_test))
# YY_test = pd.Series(Y_test.values, index=index)
# import numpy as np
# import os
# from PIL import Image

# # Create the test_images directory
# if not os.path.exists('test_images'):
#     os.mkdir('test_images')

# # Loop through each test example
# for i in range(len(X_test)):
#     # Get the pixel values and convert them to integers
#     pixels = X_test[i].astype('uint8')

#     # Get the label
#     label = YY_test[i]

#     # Create a new image from the pixel values
#     img = Image.fromarray(pixels)

#     # Save the image to a file
#     filename = f"{label}_{i}.png"
#     img.save(os.path.join('test_images', filename))

# %%
# import numpy as np
# import os

# # Define the epsilon value
# epsilon_1 = 0.1

# # Apply adversarial noise to each image in X_test
# X_test_ADN_0_1 = X_test + epsilon * np.sign(np.random.randn(*X_test.shape))

# # Clip the pixel values to the valid range of [0, 1]
# X_test_ADN_0_1 = np.clip(X_test_ADN_0_1, 0, 1)

# # # Save the new data to a CSV file
# # np.savetxt('X_test_ADN_0.1.csv', X_test_ADN_0_1, delimiter=',')

# # Create a new directory to store the images
# if not os.path.exists('test_ADN_0.1'):
#     os.makedirs('test_ADN_0.1')

# # Save each image in X_test_ADN_0_1 to the new directory
# for i in range(len(X_test)):
#     # Create a new image from the pixel values
#     img = X_test_ADN_0_1[i].reshape((28, 28, 3))
    
#     # Get the label
#     label = Y_test.iloc[i]
    
#     # Save the image to the new directory
#     filename = f'test_ADN_0.1/image_{i}_label_{label}.png'
#     plt.imsave(filename, img)

# %%
import numpy as np
import cv2
import os

def add_adversarial_noise(epsilon, X_test, Y_test):
    # Create a directory for the adversarial images
    if not os.path.exists(f"test_ADN_{epsilon}"):
        os.mkdir(f"test_ADN_{epsilon}")

    # Create an empty array to store the adversarial images
    X_test_adn = np.empty_like(X_test)

    # Loop through each image in the test set
    for i in range(len(X_test)):
        # Get the pixel values of the image
        pixels = X_test[i]
        label = Y_test.iloc[i]

        # Add adversarial noise to the image
        noisy_image = np.clip(pixels + epsilon, 0, 255)

        # Save the noisy image to the new directory
        cv2.imwrite(f"test_ADN_{epsilon}/{i}_{label}.png", noisy_image)

        # Store the noisy image in the new adversarial dataset
        X_test_adn[i] = noisy_image

    return X_test_adn, Y_test

# %%
X_test_ADV_E_0_1=add_adversarial_noise(0.1,X_test,Y_test)
X_test_ADV_E_0_2=add_adversarial_noise(0.2,X_test,Y_test)
X_test_ADV_E_0_3=add_adversarial_noise(0.3,X_test,Y_test)
X_test_ADV_E_0_4=add_adversarial_noise(0.4,X_test,Y_test)
X_test_ADV_E_0_5=add_adversarial_noise(0.5,X_test,Y_test)
X_test_ADV_E_0_6=add_adversarial_noise(0.6,X_test,Y_test)
X_test_ADV_E_0_7=add_adversarial_noise(0.7,X_test,Y_test)
X_test_ADV_E_0_8=add_adversarial_noise(0.8,X_test,Y_test)
X_test_ADV_E_0_9=add_adversarial_noise(0.9,X_test,Y_test)
X_test_ADV_E_1=add_adversarial_noise(1,X_test,Y_test)

# %%
result1[0].shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_23/569004256.py in <module>
# ----> 1 result1[0].shape
#
# NameError: name 'result1' is not defined

# %%
classes = {4:'melanocytic nevi',
6: 'melanoma',
2:'benign keratosis-like lesions',
1:'basal cell carcinoma',
5:'pyogenic granulomas and hemorrhage',
0:'Actinic keratoses and intraepithelial carcinomae',
3:'dermatofibroma'}

# %%
Label[:10]
# Out:
# 0    2
# 1    4
# 2    4
# 3    6
# 4    5
# 5    4
# 6    2
# 7    4
# 8    4
# 9    4
# Name: label, dtype: int64

# %%
l_train = np.array(Label)
l_train[1]
# Out:
# 4

# %%
f , ax = plt.subplots(2,5)
f.set_size_inches(15, 15)
k = 0
l_train = np.array(Label)
for i in range(2):
    for j in range(5):
        plt.subplots_adjust(wspace=5)
        ax[i,j].imshow(Data[k].reshape(28,28,3))
        ax[i, j].set_title(f"{classes[l_train[k]]}")
        k = k + 1
   
    plt.tight_layout()

# %%
f , ax = plt.subplots(2,5)
f.set_size_inches(15, 15)
k = 0
l_test = np.array(Y_test)
for i in range(2):
    for j in range(5):
        plt.subplots_adjust(wspace=5)
        ax[i,j].imshow(X_test[k].reshape(28,28,3))
        ax[i, j].set_title(f"{classes[l_test[k]]}")
        k = k + 1
   
    plt.tight_layout()

# %%
f , ax = plt.subplots(2,5)
f.set_size_inches(15, 15)
k = 0
l_test = np.array(Y_test)
for i in range(2):
    for j in range(5):
        plt.subplots_adjust(wspace=5)
        ax[i,j].imshow(X_test_ADV_E_0_1[0][k].reshape(28,28,3))
        ax[i, j].set_title(f"{classes[l_test[k]]}")
        k = k + 1
   
    plt.tight_layout()

# %%
f , ax = plt.subplots(2,5)
f.set_size_inches(15, 15)
k = 0
l_test = np.array(Y_test)
for i in range(2):
    for j in range(5):
        plt.subplots_adjust(wspace=5)
        ax[i,j].imshow(X_test_ADV_E_0_1[0][k].reshape(28,28,3))
        ax[i, j].set_title(f"{classes[l_test[k]]}")
        k = k + 1
   
    plt.tight_layout()

# %%
f , ax = plt.subplots(2,5)
f.set_size_inches(15, 15)
k = 0
l_test = np.array(Y_test)
for i in range(2):
    for j in range(5):
        plt.subplots_adjust(wspace=5)
        ax[i,j].imshow(X_test_ADV_E_0_1[0][k].reshape(28,28,3))
        ax[i, j].set_title(f"{classes[l_test[k]]}")
        k = k + 1
   
    plt.tight_layout()

# %%
model_CNN = Sequential()
model_CNN.add(Conv2D(32, kernel_size = (3,3), input_shape = (28, 28, 3), activation = 'relu', padding = 'same'))
model_CNN.add(BatchNormalization())


model_CNN.add(MaxPool2D(pool_size = (2,2)))


model_CNN.add(Conv2D(64, kernel_size = (3,3), activation = 'relu', padding = 'same'))
model_CNN.add(BatchNormalization())

model_CNN.add(MaxPool2D(pool_size = (2,2), padding = 'same'))
model_CNN.add(Conv2D(128, kernel_size = (3,3), activation = 'relu', padding = 'same'))
model_CNN.add(BatchNormalization())

model_CNN.add(MaxPool2D(pool_size = (2,2), padding = 'same'))

model_CNN.add(Flatten())


model_CNN.add(Dense(64, activation = 'relu'))
model_CNN.add(BatchNormalization())


model_CNN.add(Dense(32))
model_CNN.add(Activation(activation='relu'))
model_CNN.add(BatchNormalization())

model_CNN.add(Dense(16))
model_CNN.add(Activation(activation='relu'))
model_CNN.add(BatchNormalization())

model_CNN.add(Dense(7))
model_CNN.add(Activation(activation='softmax'))

optimizer = tf.keras.optimizers.Adam(learning_rate = 0.001)

model_CNN.compile(loss = 'sparse_categorical_crossentropy',
                 optimizer = optimizer,
                  metrics = ['accuracy'])
print(model_CNN.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 32)        896
#
#  batch_normalization (BatchN  (None, 28, 28, 32)       128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 64)        18496
#
#  batch_normalization_1 (Batc  (None, 14, 14, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 128)         73856
#
#  batch_normalization_2 (Batc  (None, 7, 7, 128)        512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 64)                131136
#
#  batch_normalization_3 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  activation (Activation)     (None, 32)                0
#
#  batch_normalization_4 (Batc  (None, 32)               128
#  hNormalization)
#
#  dense_2 (Dense)             (None, 16)                528
#
#  activation_1 (Activation)   (None, 16)                0
#
#  batch_normalization_5 (Batc  (None, 16)               64
#  hNormalization)
#
#  dense_3 (Dense)             (None, 7)                 119
#
#  activation_2 (Activation)   (None, 7)                 0
#
# =================================================================
# Total params: 228,455
# Trainable params: 227,783
# Non-trainable params: 672
# _________________________________________________________________
# None

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='auto')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=1, mode='auto')
history = model_CNN.fit(Data,
                    Label,
                    validation_split=0.2,
                    batch_size = 64,
                    epochs = 500,
                    callbacks = [reduce_lr])
# Out:
# Epoch 1/500
# 471/471 [==============================] - 4s 9ms/step - loss: 6.8773e-04 - accuracy: 1.0000 - val_loss: 7.5386e-04 - val_accuracy: 1.0000 - lr: 1.0000e-24
# Epoch 2/500
# 471/471 [==============================] - 4s 8ms/step - loss: 8.1134e-04 - accuracy: 1.0000 - val_loss: 7.3872e-04 - val_accuracy: 1.0000 - lr: 1.0000e-24
# Epoch 3/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.7416e-04 - accuracy: 1.0000 - val_loss: 7.0065e-04 - val_accuracy: 1.0000 - lr: 1.0000e-24
# Epoch 4/500
# 470/471 [============================>.] - ETA: 0s - loss: 7.1373e-04 - accuracy: 1.0000
# Epoch 4: ReduceLROnPlateau reducing learning rate to 1.0000001181490946e-25.
# 471/471 [==============================] - 4s 8ms/step - loss: 7.1351e-04 - accuracy: 1.0000 - val_loss: 7.6593e-04 - val_accuracy: 1.0000 - lr: 1.0000e-24
# Epoch 5/500
# 471/471 [==============================] - 4s 8ms/step - loss: 8.0599e-04 - accuracy: 1.0000 - val_loss: 8.1396e-04 - val_accuracy: 1.0000 - lr: 1.0000e-25
# Epoch 6/500
# 471/471 [==============================] - 4s 9ms/step - loss: 6.6485e-04 - accuracy: 1.0000 - val_loss: 7.8368e-04 - val_accuracy: 1.0000 - lr: 1.0000e-25
# Epoch 7/500
# 470/471 [============================>.] - ETA: 0s - loss: 7.6905e-04 - accuracy: 1.0000
# Epoch 7: ReduceLROnPlateau reducing learning rate to 1.0000001428009978e-26.
# 471/471 [==============================] - 4s 8ms/step - loss: 7.7535e-04 - accuracy: 1.0000 - val_loss: 6.9006e-04 - val_accuracy: 1.0000 - lr: 1.0000e-25
# Epoch 8/500
# 471/471 [==============================] - 4s 9ms/step - loss: 7.8332e-04 - accuracy: 1.0000 - val_loss: 7.0596e-04 - val_accuracy: 1.0000 - lr: 1.0000e-26
# Epoch 9/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.0659e-04 - accuracy: 1.0000 - val_loss: 7.3388e-04 - val_accuracy: 1.0000 - lr: 1.0000e-26
# Epoch 10/500
# 468/471 [============================>.] - ETA: 0s - loss: 7.4231e-04 - accuracy: 1.0000
# Epoch 10: ReduceLROnPlateau reducing learning rate to 1.000000142800998e-27.
# 471/471 [==============================] - 4s 8ms/step - loss: 7.4582e-04 - accuracy: 1.0000 - val_loss: 7.0696e-04 - val_accuracy: 1.0000 - lr: 1.0000e-26
# Epoch 11/500
# 471/471 [==============================] - 4s 9ms/step - loss: 6.3199e-04 - accuracy: 1.0000 - val_loss: 7.5476e-04 - val_accuracy: 1.0000 - lr: 1.0000e-27
# Epoch 12/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.3086e-04 - accuracy: 1.0000 - val_loss: 7.6753e-04 - val_accuracy: 1.0000 - lr: 1.0000e-27
# Epoch 13/500
# 469/471 [============================>.] - ETA: 0s - loss: 6.7287e-04 - accuracy: 1.0000
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1.0000001235416984e-28.
# 471/471 [==============================] - 4s 8ms/step - loss: 6.7140e-04 - accuracy: 1.0000 - val_loss: 7.1949e-04 - val_accuracy: 1.0000 - lr: 1.0000e-27
# Epoch 14/500
# 471/471 [==============================] - 5s 10ms/step - loss: 7.0476e-04 - accuracy: 1.0000 - val_loss: 6.7280e-04 - val_accuracy: 1.0000 - lr: 1.0000e-28
# Epoch 15/500
# 471/471 [==============================] - 4s 8ms/step - loss: 6.9507e-04 - accuracy: 1.0000 - val_loss: 7.2398e-04 - val_accuracy: 1.0000 - lr: 1.0000e-28
# Epoch 16/500
# 470/471 [============================>.] - ETA: 0s - loss: 6.0831e-04 - accuracy: 1.0000
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.0000001235416985e-29.
# 471/471 [==============================] - 4s 8ms/step - loss: 6.1433e-04 - accuracy: 1.0000 - val_loss: 6.9666e-04 - val_accuracy: 1.0000 - lr: 1.0000e-28
# Epoch 17/500
# 471/471 [==============================] - 4s 9ms/step - loss: 7.3761e-04 - accuracy: 1.0000 - val_loss: 6.6414e-04 - val_accuracy: 1.0000 - lr: 1.0000e-29
# Epoch 18/500
# 471/471 [==============================] - 4s 8ms/step - loss: 8.5682e-04 - accuracy: 0.9999 - val_loss: 6.9925e-04 - val_accuracy: 1.0000 - lr: 1.0000e-29
# Epoch 19/500
# 467/471 [============================>.] - ETA: 0s - loss: 7.6910e-04 - accuracy: 1.0000
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.0000001536343539e-30.
# 471/471 [==============================] - 4s 8ms/step - loss: 7.6705e-04 - accuracy: 1.0000 - val_loss: 7.3419e-04 - val_accuracy: 1.0000 - lr: 1.0000e-29
# Epoch 20/500
# 471/471 [==============================] - 4s 9ms/step - loss: 7.9924e-04 - accuracy: 1.0000 - val_loss: 6.7228e-04 - val_accuracy: 1.0000 - lr: 1.0000e-30
# Epoch 21/500
# 471/471 [==============================] - 4s 8ms/step - loss: 6.6517e-04 - accuracy: 1.0000 - val_loss: 7.1825e-04 - val_accuracy: 1.0000 - lr: 1.0000e-30
# Epoch 22/500
# 468/471 [============================>.] - ETA: 0s - loss: 6.8502e-04 - accuracy: 1.0000
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.000000191250173e-31.
# 471/471 [==============================] - 5s 10ms/step - loss: 6.8619e-04 - accuracy: 1.0000 - val_loss: 7.3468e-04 - val_accuracy: 1.0000 - lr: 1.0000e-30
# Epoch 23/500
# 471/471 [==============================] - 4s 8ms/step - loss: 6.8980e-04 - accuracy: 1.0000 - val_loss: 6.9510e-04 - val_accuracy: 1.0000 - lr: 1.0000e-31
# Epoch 24/500
# 471/471 [==============================] - 4s 8ms/step - loss: 8.0442e-04 - accuracy: 1.0000 - val_loss: 6.3970e-04 - val_accuracy: 1.0000 - lr: 1.0000e-31
# Epoch 25/500
# 471/471 [==============================] - 4s 9ms/step - loss: 7.3250e-04 - accuracy: 1.0000 - val_loss: 6.6861e-04 - val_accuracy: 1.0000 - lr: 1.0000e-31
# Epoch 26/500
# 471/471 [==============================] - 4s 8ms/step - loss: 6.2235e-04 - accuracy: 1.0000 - val_loss: 6.9087e-04 - val_accuracy: 1.0000 - lr: 1.0000e-31
# Epoch 27/500
# 464/471 [============================>.] - ETA: 0s - loss: 7.0828e-04 - accuracy: 1.0000
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.0000002147600601e-32.
# 471/471 [==============================] - 4s 8ms/step - loss: 7.0526e-04 - accuracy: 1.0000 - val_loss: 7.5329e-04 - val_accuracy: 1.0000 - lr: 1.0000e-31
# Epoch 28/500
# 471/471 [==============================] - 4s 8ms/step - loss: 8.0233e-04 - accuracy: 0.9999 - val_loss: 7.7844e-04 - val_accuracy: 1.0000 - lr: 1.0000e-32
# Epoch 29/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.0444e-04 - accuracy: 1.0000 - val_loss: 7.5127e-04 - val_accuracy: 1.0000 - lr: 1.0000e-32
# Epoch 30/500
# 471/471 [==============================] - ETA: 0s - loss: 6.3238e-04 - accuracy: 1.0000
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.0000002441474188e-33.
# 471/471 [==============================] - 4s 9ms/step - loss: 6.3238e-04 - accuracy: 1.0000 - val_loss: 7.7646e-04 - val_accuracy: 1.0000 - lr: 1.0000e-32
# Epoch 31/500
# 471/471 [==============================] - 4s 9ms/step - loss: 6.5578e-04 - accuracy: 1.0000 - val_loss: 7.5721e-04 - val_accuracy: 1.0000 - lr: 1.0000e-33
# Epoch 32/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.3009e-04 - accuracy: 1.0000 - val_loss: 7.3924e-04 - val_accuracy: 1.0000 - lr: 1.0000e-33
# Epoch 33/500
# 465/471 [============================>.] - ETA: 0s - loss: 7.0729e-04 - accuracy: 1.0000
# Epoch 33: ReduceLROnPlateau reducing learning rate to 1.0000002074132203e-34.
# 471/471 [==============================] - 4s 8ms/step - loss: 7.0398e-04 - accuracy: 1.0000 - val_loss: 7.0169e-04 - val_accuracy: 1.0000 - lr: 1.0000e-33
# Epoch 34/500
# 471/471 [==============================] - 4s 8ms/step - loss: 6.8902e-04 - accuracy: 1.0000 - val_loss: 7.2940e-04 - val_accuracy: 1.0000 - lr: 1.0000e-34
# Epoch 35/500
# 471/471 [==============================] - 4s 8ms/step - loss: 6.8906e-04 - accuracy: 1.0000 - val_loss: 7.1764e-04 - val_accuracy: 1.0000 - lr: 1.0000e-34
# Epoch 36/500
# 469/471 [============================>.] - ETA: 0s - loss: 6.5067e-04 - accuracy: 1.0000
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.0000001614954722e-35.
# 471/471 [==============================] - 4s 9ms/step - loss: 6.4967e-04 - accuracy: 1.0000 - val_loss: 7.4737e-04 - val_accuracy: 1.0000 - lr: 1.0000e-34
# Epoch 37/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.5991e-04 - accuracy: 1.0000 - val_loss: 7.8696e-04 - val_accuracy: 1.0000 - lr: 1.0000e-35
# Epoch 38/500
# 471/471 [==============================] - 4s 9ms/step - loss: 7.6987e-04 - accuracy: 0.9999 - val_loss: 7.2267e-04 - val_accuracy: 1.0000 - lr: 1.0000e-35
# Epoch 39/500
# 469/471 [============================>.] - ETA: 0s - loss: 7.4202e-04 - accuracy: 1.0000
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1.0000001614954723e-36.
# 471/471 [==============================] - 4s 9ms/step - loss: 7.4082e-04 - accuracy: 1.0000 - val_loss: 7.9227e-04 - val_accuracy: 1.0000 - lr: 1.0000e-35
# Epoch 40/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.5493e-04 - accuracy: 1.0000 - val_loss: 7.1021e-04 - val_accuracy: 1.0000 - lr: 1.0000e-36
# Epoch 41/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.2904e-04 - accuracy: 1.0000 - val_loss: 6.7633e-04 - val_accuracy: 1.0000 - lr: 1.0000e-36
# Epoch 42/500
# 467/471 [============================>.] - ETA: 0s - loss: 6.7531e-04 - accuracy: 1.0000
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1.0000001256222317e-37.
# 471/471 [==============================] - 4s 9ms/step - loss: 6.7589e-04 - accuracy: 1.0000 - val_loss: 7.5111e-04 - val_accuracy: 1.0000 - lr: 1.0000e-36
# Epoch 43/500
# 471/471 [==============================] - 4s 8ms/step - loss: 6.6712e-04 - accuracy: 1.0000 - val_loss: 6.9419e-04 - val_accuracy: 1.0000 - lr: 1.0000e-37
# Epoch 44/500
# 471/471 [==============================] - 4s 8ms/step - loss: 6.6687e-04 - accuracy: 1.0000 - val_loss: 7.6643e-04 - val_accuracy: 1.0000 - lr: 1.0000e-37
# Epoch 45/500
# 465/471 [============================>.] - ETA: 0s - loss: 7.6484e-04 - accuracy: 0.9999
# Epoch 45: ReduceLROnPlateau reducing learning rate to 1.0000001032014561e-38.
# 471/471 [==============================] - 4s 9ms/step - loss: 7.8710e-04 - accuracy: 0.9999 - val_loss: 7.3796e-04 - val_accuracy: 1.0000 - lr: 1.0000e-37
# Epoch 46/500
# 471/471 [==============================] - 4s 9ms/step - loss: 7.8687e-04 - accuracy: 1.0000 - val_loss: 6.9434e-04 - val_accuracy: 1.0000 - lr: 1.0000e-38
# Epoch 47/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.3793e-04 - accuracy: 1.0000 - val_loss: 7.9547e-04 - val_accuracy: 1.0000 - lr: 1.0000e-38
# Epoch 48/500
# 468/471 [============================>.] - ETA: 0s - loss: 6.5408e-04 - accuracy: 1.0000
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1.0000000751754869e-39.
# 471/471 [==============================] - 4s 8ms/step - loss: 6.6447e-04 - accuracy: 1.0000 - val_loss: 7.4727e-04 - val_accuracy: 1.0000 - lr: 1.0000e-38
# Epoch 49/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.2094e-04 - accuracy: 1.0000 - val_loss: 6.8593e-04 - val_accuracy: 1.0000 - lr: 1.0000e-39
# Epoch 50/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.0651e-04 - accuracy: 1.0000 - val_loss: 6.7389e-04 - val_accuracy: 1.0000 - lr: 1.0000e-39
# Epoch 51/500
# 464/471 [============================>.] - ETA: 0s - loss: 8.0500e-04 - accuracy: 0.9999
# Epoch 51: ReduceLROnPlateau reducing learning rate to 1.0000002153053334e-40.
# 471/471 [==============================] - 4s 8ms/step - loss: 8.0208e-04 - accuracy: 0.9999 - val_loss: 7.2134e-04 - val_accuracy: 1.0000 - lr: 1.0000e-39
# Epoch 52/500
# 471/471 [==============================] - 4s 8ms/step - loss: 6.9150e-04 - accuracy: 1.0000 - val_loss: 6.3491e-04 - val_accuracy: 1.0000 - lr: 9.9999e-41
# Epoch 53/500
# 471/471 [==============================] - 4s 8ms/step - loss: 6.4107e-04 - accuracy: 1.0000 - val_loss: 6.8000e-04 - val_accuracy: 1.0000 - lr: 9.9999e-41
# Epoch 54/500
# 471/471 [==============================] - ETA: 0s - loss: 7.0468e-04 - accuracy: 1.0000
# Epoch 54: ReduceLROnPlateau reducing learning rate to 9.99994610111476e-42.
# 471/471 [==============================] - 4s 8ms/step - loss: 7.0468e-04 - accuracy: 1.0000 - val_loss: 6.7499e-04 - val_accuracy: 1.0000 - lr: 9.9999e-41
# Epoch 55/500
# 471/471 [==============================] - 4s 9ms/step - loss: 6.0790e-04 - accuracy: 1.0000 - val_loss: 6.8879e-04 - val_accuracy: 1.0000 - lr: 9.9997e-42
# Epoch 56/500
# 471/471 [==============================] - 4s 9ms/step - loss: 9.6221e-04 - accuracy: 0.9999 - val_loss: 7.2284e-04 - val_accuracy: 1.0000 - lr: 9.9997e-42
# Epoch 57/500
# 465/471 [============================>.] - ETA: 0s - loss: 7.2627e-04 - accuracy: 1.0000
# Epoch 57: ReduceLROnPlateau reducing learning rate to 9.999665841421895e-43.
# 471/471 [==============================] - 4s 8ms/step - loss: 7.2547e-04 - accuracy: 1.0000 - val_loss: 7.3902e-04 - val_accuracy: 1.0000 - lr: 9.9997e-42
# Epoch 58/500
# 471/471 [==============================] - 4s 8ms/step - loss: 6.6829e-04 - accuracy: 1.0000 - val_loss: 7.7433e-04 - val_accuracy: 1.0000 - lr: 1.0005e-42
# Epoch 59/500
# 471/471 [==============================] - 4s 8ms/step - loss: 6.8139e-04 - accuracy: 1.0000 - val_loss: 7.1087e-04 - val_accuracy: 1.0000 - lr: 1.0005e-42
# Epoch 60/500
# 465/471 [============================>.] - ETA: 0s - loss: 7.2225e-04 - accuracy: 1.0000
# Epoch 60: ReduceLROnPlateau reducing learning rate to 1.0005271035279195e-43.
# 471/471 [==============================] - 4s 8ms/step - loss: 7.2339e-04 - accuracy: 1.0000 - val_loss: 6.4947e-04 - val_accuracy: 1.0000 - lr: 1.0005e-42
# Epoch 61/500
# 471/471 [==============================] - 4s 9ms/step - loss: 6.4985e-04 - accuracy: 1.0000 - val_loss: 7.5699e-04 - val_accuracy: 1.0000 - lr: 9.9492e-44
# Epoch 62/500
# 471/471 [==============================] - 4s 8ms/step - loss: 6.9692e-04 - accuracy: 1.0000 - val_loss: 7.2397e-04 - val_accuracy: 1.0000 - lr: 9.9492e-44
# Epoch 63/500
# 465/471 [============================>.] - ETA: 0s - loss: 7.1941e-04 - accuracy: 1.0000
# Epoch 63: ReduceLROnPlateau reducing learning rate to 9.949219096706202e-45.
# 471/471 [==============================] - 4s 9ms/step - loss: 7.1626e-04 - accuracy: 1.0000 - val_loss: 7.3663e-04 - val_accuracy: 1.0000 - lr: 9.9492e-44
# Epoch 64/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.9616e-04 - accuracy: 1.0000 - val_loss: 7.2649e-04 - val_accuracy: 1.0000 - lr: 9.8091e-45
# Epoch 65/500
# 471/471 [==============================] - 4s 9ms/step - loss: 6.7223e-04 - accuracy: 1.0000 - val_loss: 7.9541e-04 - val_accuracy: 1.0000 - lr: 9.8091e-45
# Epoch 66/500
# 468/471 [============================>.] - ETA: 0s - loss: 6.6079e-04 - accuracy: 1.0000
# Epoch 66: ReduceLROnPlateau reducing learning rate to 9.80908925027372e-46.
# 471/471 [==============================] - 4s 8ms/step - loss: 6.5975e-04 - accuracy: 1.0000 - val_loss: 7.0904e-04 - val_accuracy: 1.0000 - lr: 9.8091e-45
# Epoch 67/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.5303e-04 - accuracy: 1.0000 - val_loss: 7.7253e-04 - val_accuracy: 1.0000 - lr: 1.4013e-45
# Epoch 68/500
# 471/471 [==============================] - 4s 9ms/step - loss: 6.1774e-04 - accuracy: 1.0000 - val_loss: 7.3929e-04 - val_accuracy: 1.0000 - lr: 1.4013e-45
# Epoch 69/500
# 468/471 [============================>.] - ETA: 0s - loss: 7.8355e-04 - accuracy: 1.0000
# Epoch 69: ReduceLROnPlateau reducing learning rate to 1.4012984643248171e-46.
# 471/471 [==============================] - 4s 8ms/step - loss: 7.8290e-04 - accuracy: 1.0000 - val_loss: 6.9530e-04 - val_accuracy: 1.0000 - lr: 1.4013e-45
# Epoch 70/500
# 471/471 [==============================] - 4s 9ms/step - loss: 7.6719e-04 - accuracy: 0.9999 - val_loss: 7.2401e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 71/500
# 471/471 [==============================] - 4s 9ms/step - loss: 7.8174e-04 - accuracy: 1.0000 - val_loss: 6.8615e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 72/500
# 471/471 [==============================] - 4s 8ms/step - loss: 8.0070e-04 - accuracy: 0.9999 - val_loss: 6.9536e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 73/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.5336e-04 - accuracy: 1.0000 - val_loss: 7.2705e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 74/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.1124e-04 - accuracy: 1.0000 - val_loss: 7.3901e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 75/500
# 471/471 [==============================] - 4s 8ms/step - loss: 6.7956e-04 - accuracy: 1.0000 - val_loss: 7.2367e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 76/500
# 471/471 [==============================] - 4s 9ms/step - loss: 7.7594e-04 - accuracy: 1.0000 - val_loss: 6.8230e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 77/500
# 471/471 [==============================] - 4s 8ms/step - loss: 6.5883e-04 - accuracy: 1.0000 - val_loss: 7.3702e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 78/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.8156e-04 - accuracy: 1.0000 - val_loss: 7.6563e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 79/500
# 471/471 [==============================] - 4s 9ms/step - loss: 8.2453e-04 - accuracy: 0.9999 - val_loss: 7.4078e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 80/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.5308e-04 - accuracy: 0.9999 - val_loss: 6.9745e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 81/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.3347e-04 - accuracy: 0.9999 - val_loss: 6.9321e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 82/500
# 471/471 [==============================] - 4s 8ms/step - loss: 8.5532e-04 - accuracy: 1.0000 - val_loss: 6.5923e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 83/500
# 471/471 [==============================] - 4s 8ms/step - loss: 8.1495e-04 - accuracy: 1.0000 - val_loss: 6.9446e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 84/500
# 471/471 [==============================] - 4s 9ms/step - loss: 6.9476e-04 - accuracy: 1.0000 - val_loss: 7.3445e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 85/500
# 471/471 [==============================] - 4s 8ms/step - loss: 6.7013e-04 - accuracy: 1.0000 - val_loss: 7.2694e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 86/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.1984e-04 - accuracy: 1.0000 - val_loss: 8.0885e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 87/500
# 471/471 [==============================] - 5s 10ms/step - loss: 8.4115e-04 - accuracy: 1.0000 - val_loss: 6.9884e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 88/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.2034e-04 - accuracy: 0.9999 - val_loss: 6.9097e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 89/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.5131e-04 - accuracy: 1.0000 - val_loss: 6.6420e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 90/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.2590e-04 - accuracy: 1.0000 - val_loss: 7.4681e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 91/500
# 471/471 [==============================] - 4s 8ms/step - loss: 6.6365e-04 - accuracy: 1.0000 - val_loss: 6.9971e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 92/500
# 471/471 [==============================] - 4s 8ms/step - loss: 6.7219e-04 - accuracy: 1.0000 - val_loss: 6.0548e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 93/500
# 471/471 [==============================] - 4s 8ms/step - loss: 6.8227e-04 - accuracy: 1.0000 - val_loss: 7.7609e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 94/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.0775e-04 - accuracy: 1.0000 - val_loss: 7.1334e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 95/500
# 471/471 [==============================] - 4s 9ms/step - loss: 6.5363e-04 - accuracy: 1.0000 - val_loss: 7.2861e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 96/500
# 471/471 [==============================] - 4s 8ms/step - loss: 6.6360e-04 - accuracy: 1.0000 - val_loss: 8.0481e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 97/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.5433e-04 - accuracy: 1.0000 - val_loss: 6.9089e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 98/500
# 471/471 [==============================] - 4s 9ms/step - loss: 7.5746e-04 - accuracy: 1.0000 - val_loss: 7.5935e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 99/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.0506e-04 - accuracy: 1.0000 - val_loss: 7.0458e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 100/500
# 471/471 [==============================] - 4s 8ms/step - loss: 6.3036e-04 - accuracy: 1.0000 - val_loss: 7.1133e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 101/500
# 471/471 [==============================] - 4s 9ms/step - loss: 6.5715e-04 - accuracy: 1.0000 - val_loss: 7.2765e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 102/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.1444e-04 - accuracy: 1.0000 - val_loss: 7.4993e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 103/500
# 471/471 [==============================] - 4s 9ms/step - loss: 6.7291e-04 - accuracy: 1.0000 - val_loss: 7.1275e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 104/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.6455e-04 - accuracy: 0.9999 - val_loss: 7.3590e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 105/500
# 471/471 [==============================] - 4s 8ms/step - loss: 6.9284e-04 - accuracy: 1.0000 - val_loss: 6.6533e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 106/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.7986e-04 - accuracy: 1.0000 - val_loss: 6.9086e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 107/500
# 471/471 [==============================] - 4s 9ms/step - loss: 7.7828e-04 - accuracy: 0.9999 - val_loss: 7.1449e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 108/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.3738e-04 - accuracy: 1.0000 - val_loss: 6.8482e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 109/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.5066e-04 - accuracy: 1.0000 - val_loss: 7.7270e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 110/500
# 471/471 [==============================] - 4s 9ms/step - loss: 6.4177e-04 - accuracy: 1.0000 - val_loss: 7.1492e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 111/500
# 471/471 [==============================] - 4s 9ms/step - loss: 6.6952e-04 - accuracy: 1.0000 - val_loss: 6.9817e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 112/500
# 471/471 [==============================] - 4s 9ms/step - loss: 7.6379e-04 - accuracy: 0.9999 - val_loss: 7.2478e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 113/500
# 471/471 [==============================] - 4s 8ms/step - loss: 6.7462e-04 - accuracy: 1.0000 - val_loss: 7.3108e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 114/500
# 471/471 [==============================] - 4s 9ms/step - loss: 6.3787e-04 - accuracy: 1.0000 - val_loss: 7.0150e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 115/500
# 471/471 [==============================] - 4s 9ms/step - loss: 6.9640e-04 - accuracy: 1.0000 - val_loss: 7.7296e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 116/500
# 471/471 [==============================] - 4s 9ms/step - loss: 7.6672e-04 - accuracy: 1.0000 - val_loss: 7.3169e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 117/500
# 471/471 [==============================] - 4s 8ms/step - loss: 8.7547e-04 - accuracy: 0.9999 - val_loss: 6.8278e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 118/500
# 471/471 [==============================] - 4s 9ms/step - loss: 6.9342e-04 - accuracy: 1.0000 - val_loss: 6.9518e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 119/500
# 471/471 [==============================] - 4s 9ms/step - loss: 7.1783e-04 - accuracy: 1.0000 - val_loss: 7.1555e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 120/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.2418e-04 - accuracy: 1.0000 - val_loss: 6.8986e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 121/500
# 471/471 [==============================] - 4s 8ms/step - loss: 6.9071e-04 - accuracy: 1.0000 - val_loss: 7.0382e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 122/500
# 471/471 [==============================] - 4s 8ms/step - loss: 8.0187e-04 - accuracy: 1.0000 - val_loss: 6.5142e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 123/500
# 471/471 [==============================] - 4s 9ms/step - loss: 7.0534e-04 - accuracy: 1.0000 - val_loss: 7.1666e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 124/500
# 471/471 [==============================] - 4s 8ms/step - loss: 8.3316e-04 - accuracy: 0.9999 - val_loss: 7.0750e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 125/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.1883e-04 - accuracy: 1.0000 - val_loss: 7.7015e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 126/500
# 471/471 [==============================] - 4s 9ms/step - loss: 6.9847e-04 - accuracy: 1.0000 - val_loss: 7.4661e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 127/500
# 471/471 [==============================] - 4s 9ms/step - loss: 9.5585e-04 - accuracy: 0.9999 - val_loss: 7.5532e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 128/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.3138e-04 - accuracy: 1.0000 - val_loss: 6.6776e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 129/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.6766e-04 - accuracy: 1.0000 - val_loss: 7.1184e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 130/500
# 471/471 [==============================] - 4s 8ms/step - loss: 6.4901e-04 - accuracy: 1.0000 - val_loss: 7.5927e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 131/500
# 471/471 [==============================] - 4s 9ms/step - loss: 7.2710e-04 - accuracy: 1.0000 - val_loss: 7.9063e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 132/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.6992e-04 - accuracy: 1.0000 - val_loss: 7.0640e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 133/500
# 471/471 [==============================] - 4s 8ms/step - loss: 8.4127e-04 - accuracy: 0.9999 - val_loss: 6.9381e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 134/500
# 471/471 [==============================] - 4s 9ms/step - loss: 7.8485e-04 - accuracy: 0.9999 - val_loss: 7.1042e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 135/500
# 471/471 [==============================] - 4s 9ms/step - loss: 7.1639e-04 - accuracy: 1.0000 - val_loss: 6.4773e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 136/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.9565e-04 - accuracy: 0.9999 - val_loss: 6.9001e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 137/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.8508e-04 - accuracy: 1.0000 - val_loss: 7.8137e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 138/500
# 471/471 [==============================] - 4s 9ms/step - loss: 7.3050e-04 - accuracy: 1.0000 - val_loss: 7.0421e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 139/500
# 471/471 [==============================] - 4s 8ms/step - loss: 8.1441e-04 - accuracy: 0.9999 - val_loss: 7.3926e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 140/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.6978e-04 - accuracy: 0.9999 - val_loss: 7.0925e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 141/500
# 471/471 [==============================] - 4s 9ms/step - loss: 7.6600e-04 - accuracy: 1.0000 - val_loss: 7.6818e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 142/500
# 471/471 [==============================] - 4s 9ms/step - loss: 7.0322e-04 - accuracy: 1.0000 - val_loss: 6.7857e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 143/500
# 471/471 [==============================] - 5s 10ms/step - loss: 7.3490e-04 - accuracy: 1.0000 - val_loss: 6.7065e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 144/500
# 471/471 [==============================] - 4s 8ms/step - loss: 8.4949e-04 - accuracy: 1.0000 - val_loss: 7.0471e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 145/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.2269e-04 - accuracy: 1.0000 - val_loss: 7.4351e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 146/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.8494e-04 - accuracy: 1.0000 - val_loss: 7.7397e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 147/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.0472e-04 - accuracy: 1.0000 - val_loss: 7.5543e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 148/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.6895e-04 - accuracy: 1.0000 - val_loss: 7.2379e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 149/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.5876e-04 - accuracy: 1.0000 - val_loss: 7.6609e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 150/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.4387e-04 - accuracy: 1.0000 - val_loss: 7.0966e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 151/500
# 471/471 [==============================] - 4s 9ms/step - loss: 6.4121e-04 - accuracy: 1.0000 - val_loss: 7.4596e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 152/500
# 471/471 [==============================] - 4s 8ms/step - loss: 6.9925e-04 - accuracy: 1.0000 - val_loss: 7.4327e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 153/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.7825e-04 - accuracy: 0.9999 - val_loss: 6.7870e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 154/500
# 471/471 [==============================] - 4s 9ms/step - loss: 7.2485e-04 - accuracy: 1.0000 - val_loss: 6.9848e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 155/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.0610e-04 - accuracy: 1.0000 - val_loss: 7.1604e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 156/500
# 471/471 [==============================] - 4s 8ms/step - loss: 6.5223e-04 - accuracy: 1.0000 - val_loss: 7.5695e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 157/500
# 471/471 [==============================] - 4s 9ms/step - loss: 6.4360e-04 - accuracy: 1.0000 - val_loss: 6.9576e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 158/500
# 471/471 [==============================] - 4s 8ms/step - loss: 6.6629e-04 - accuracy: 1.0000 - val_loss: 7.1313e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 159/500
# 471/471 [==============================] - 5s 10ms/step - loss: 6.8775e-04 - accuracy: 1.0000 - val_loss: 7.4290e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 160/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.8423e-04 - accuracy: 1.0000 - val_loss: 6.5948e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 161/500
# 471/471 [==============================] - 4s 8ms/step - loss: 6.8176e-04 - accuracy: 1.0000 - val_loss: 7.3512e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 162/500
# 471/471 [==============================] - 4s 8ms/step - loss: 6.7420e-04 - accuracy: 1.0000 - val_loss: 7.5838e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 163/500
# 471/471 [==============================] - 4s 8ms/step - loss: 6.9295e-04 - accuracy: 1.0000 - val_loss: 7.0235e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 164/500
# 471/471 [==============================] - 4s 8ms/step - loss: 6.4416e-04 - accuracy: 1.0000 - val_loss: 7.0273e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 165/500
# 471/471 [==============================] - 4s 9ms/step - loss: 6.5114e-04 - accuracy: 1.0000 - val_loss: 6.8193e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 166/500
# 471/471 [==============================] - 4s 8ms/step - loss: 7.1556e-04 - accuracy: 1.0000 - val_loss: 7.8403e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 167/500
# 471/471 [==============================] - 4s 9ms/step - loss: 8.1033e-04 - accuracy: 0.9999 - val_loss: 7.7383e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 168/500
# 471/471 [==============================] - 4s 9ms/step - loss: 7.0133e-04 - accuracy: 1.0000 - val_loss: 7.1906e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 169/500
# 471/471 [==============================] - 4s 8ms/step - loss: 6.5571e-04 - accuracy: 1.0000 - val_loss: 7.2629e-04 - val_accuracy: 1.0000 - lr: 0.0000e+00
# Epoch 170/500
# 471/471 [==============================] - ETA: 0s - loss: 7.9508e-04 - accuracy: 0.9999

# %%
results = model_CNN.evaluate(X_test , Y_test, verbose=0)

print("CNN Model Test Results")
print("        Test Loss: {:.5f}".format(results[0]))
print("    Test Accuracy: {:.2f}%".format(results[1] * 100))
# Out:
# CNN Model Test Results
#         Test Loss: 1.35480
#     Test Accuracy: 76.39%

# %%
import tensorflow as tf

def generate_adversarial_noise(X_test, Y_test, model, epsilon):
     # Create a directory for the adversarial images
    if not os.path.exists(f"test_ADN_{epsilon}"):
        os.mkdir(f"test_ADN_{epsilon}")


    # Create a copy of the input image
    X_test_adn = X_test.copy()

    # Set the input tensor to be trainable
    X_test_adn = tf.Variable(X_test_adn, dtype=tf.float32)

    # Create a one-hot encoding of the target label
    Y_test_onehot = tf.one_hot(Y_test, depth=7)

    # Calculate the gradients of the loss with respect to the input
    with tf.GradientTape() as tape:
        prediction = model(X_test_adn)
        loss = tf.keras.losses.categorical_crossentropy(Y_test_onehot, prediction)
    gradients = tape.gradient(loss, X_test_adn)

    # Get the sign of the gradients
    signed_gradients = tf.sign(gradients)

    # Add the noise to the image
    X_test_adn.assign_add(epsilon * signed_gradients)

    # Clip the image to the valid pixel range
    X_test_adn = tf.clip_by_value(X_test_adn, 0, 255)
    

    # Convert the tensor back to a numpy array
    X_test_adn = X_test_adn.numpy()
    
        # Loop through each image in the test set
    for i in range(len(X_test_adn)):
        # Get the pixel values of the image
        pixels = X_test_adn[i]
        label = Y_test.iloc[i]

        # Save the noisy image to the new directory
        cv2.imwrite(f"test_ADN_{epsilon}/{i}_{label}.png", pixels)

    return X_test_adn

# %%
X_text_noise_01=generate_adversarial_noise(X_test, Y_test, model_CNN, 0.1)
X_text_noise_02=generate_adversarial_noise(X_test, Y_test, model_CNN, 0.2)
X_text_noise_03=generate_adversarial_noise(X_test, Y_test, model_CNN, 0.3)
X_text_noise_04=generate_adversarial_noise(X_test, Y_test, model_CNN, 0.4)
X_text_noise_05=generate_adversarial_noise(X_test, Y_test, model_CNN, 0.5)
X_text_noise_06=generate_adversarial_noise(X_test, Y_test, model_CNN, 0.6)
X_text_noise_07=generate_adversarial_noise(X_test, Y_test, model_CNN, 0.7)
X_text_noise_08=generate_adversarial_noise(X_test, Y_test, model_CNN, 0.8)
X_text_noise_09=generate_adversarial_noise(X_test, Y_test, model_CNN, 0.9)
X_text_noise_10=generate_adversarial_noise(X_test, Y_test, model_CNN, 1)

ALL_test_datasets=[X_test,X_text_noise_01,X_text_noise_02,X_text_noise_03,X_text_noise_04,X_text_noise_05,X_text_noise_06,X_text_noise_07,X_text_noise_08,X_text_noise_09,X_text_noise_10]

# %%
def evaluate(X_test_noise,Y_test):
    
    results = model_CNN.evaluate(X_test_noise , Y_test, verbose=0)
    return results

# %%
for i in range(11):
    res=evaluate(ALL_test_datasets[i],Y_test)
    print(f"Test on {i}")
    print("        Test Loss: {:.5f}".format(res[0]))
    print("    Test Accuracy: {:.2f}%".format(res[1] * 100))
# Out:
# Test on 0
#         Test Loss: 0.07703
#     Test Accuracy: 98.05%
# Test on 1
#         Test Loss: 0.12609
#     Test Accuracy: 97.09%
# Test on 2
#         Test Loss: 0.19920
#     Test Accuracy: 95.71%
# Test on 3
#         Test Loss: 0.33412
#     Test Accuracy: 91.69%
# Test on 4
#         Test Loss: 0.59530
#     Test Accuracy: 82.51%
# Test on 5
#         Test Loss: 1.01500
#     Test Accuracy: 69.49%
# Test on 6
#         Test Loss: 1.56533
#     Test Accuracy: 55.12%
# Test on 7
#         Test Loss: 2.19294
#     Test Accuracy: 44.42%
# Test on 8
#         Test Loss: 2.83853
#     Test Accuracy: 36.86%
# Test on 9
#         Test Loss: 3.47043
#     Test Accuracy: 30.38%
# Test on 10
#         Test Loss: 4.07637
#     Test Accuracy: 25.92%

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %%
from sklearn.metrics import confusion_matrix , classification_report

y_true_CNN = list(Y_test)
y_pred_CNN = model_CNN.predict(X_test)
y_pred_CNN = list(map(lambda x: np.argmax(x), y_pred_CNN))
print("Predicting First Ten Rows:")
print('Y Actual Values :' , y_true_CNN[0:10])
print('Y Predicted Values :' , y_pred_CNN[0:10])
# Out:
# 63/63 [==============================] - 0s 3ms/step
# Predicting First Ten Rows:
# Y Actual Values : [4, 4, 4, 4, 1, 4, 4, 4, 4, 2]
# Y Predicted Values : [4, 4, 4, 4, 1, 4, 4, 4, 4, 2]

# %%
cm_CNN = confusion_matrix(y_true_CNN,y_pred_CNN,labels=classes_labels)
print(confusion_matrix(y_true_CNN,y_pred_CNN,labels=classes_labels))
sns.heatmap(cm_CNN, annot = True, fmt='')
# Out:
# [[ 100   76    0   34    0    9    9]
#  [  37 1226    1   53    0   10    0]
#  [   2   10   12    1    0    9    3]
#  [  27   87    1  100    0    4    3]
#  [   0    7    0    3   19    2    1]
#  [   7   23    0    5    0   48   13]
#  [  16    7    0    8    0   10   20]]
# <AxesSubplot:>

# %%
#training acc vs testing acc graph
plt.plot(history.history["accuracy"] , 'ro-' , label = "Training Accuracy")
plt.plot(history.history["val_accuracy"] , 'go-' , label = "Testing Accuracy")
plt.legend()
plt.show()

# %%
#predicting
y_pred_CNN  = model_CNN.predict(X_test)
target_names = [f"{classes[i]}" for i in range(7)]
y_pred_CNN = list(map(lambda x: np.argmax(x), y_pred_CNN))
print("CNN Model Prediction Results")
print(classification_report(Y_test , y_pred_CNN,target_names=target_names))
# Out:
# 63/63 [==============================] - 0s 3ms/step
# CNN Model Prediction Results
#                                                   precision    recall  f1-score   support
#
# Actinic keratoses and intraepithelial carcinomae       0.41      0.33      0.36        61
#                             basal cell carcinoma       0.52      0.50      0.51        96
#                    benign keratosis-like lesions       0.53      0.44      0.48       228
#                                   dermatofibroma       0.86      0.32      0.47        37
#                                 melanocytic nevi       0.85      0.92      0.89      1327
#               pyogenic granulomas and hemorrhage       1.00      0.59      0.75        32
#                                         melanoma       0.49      0.45      0.47       222
#
#                                         accuracy                           0.76      2003
#                                        macro avg       0.67      0.51      0.56      2003
#                                     weighted avg       0.75      0.76      0.75      2003

# %%
# Layers definitions
from keras import backend as K
for l in range(len(model_CNN.layers)):
    print(l, model_CNN.layers[l])
# Out:
# 0 <keras.layers.convolutional.conv2d.Conv2D object at 0x7dd5940384d0>
# 1 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7dd594038610>
# 2 <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x7dd594073590>
# 3 <keras.layers.convolutional.conv2d.Conv2D object at 0x7dd5a5a4a610>
# 4 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7dd579d2a650>
# 5 <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x7dd579d38f10>
# 6 <keras.layers.convolutional.conv2d.Conv2D object at 0x7dd579d3cfd0>
# 7 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7dd5b9ba7910>
# 8 <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x7dd597ad9610>
# 9 <keras.layers.reshaping.flatten.Flatten object at 0x7dd579d4d4d0>
# 10 <keras.layers.core.dense.Dense object at 0x7dd5940626d0>
# 11 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7dd579cda9d0>
# 12 <keras.layers.core.dense.Dense object at 0x7dd5b9d91c10>
# 13 <keras.layers.core.activation.Activation object at 0x7dd579d2a4d0>
# 14 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7dd579cebf50>
# 15 <keras.layers.core.dense.Dense object at 0x7dd579cda590>
# 16 <keras.layers.core.activation.Activation object at 0x7dd579cf6550>
# 17 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7dd5b9737210>
# 18 <keras.layers.core.dense.Dense object at 0x7dd59400fcd0>
# 19 <keras.layers.core.activation.Activation object at 0x7dd579ce8e50>

# %%
model_CNN.layers[-2]

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"
kerasBKED = os.environ["KERAS_BACKEND"] 
print(kerasBKED)
# Out:
# tensorflow

# %% [markdown]
# ## Separating Features Layers from the CNN Model

# %%
import tensorflow as tf
# feature_extractor = tf.keras.Model(inputs=model_CNN.input, 
#                                     outputs=model_CNN.get_layer(-2).output)
# output_layers_model =tf.keras.Model(inputs=model_CNN.input, outputs=model_CNN.output)
# cnn_layer_output = model_CNN.layers[-2].output
# cnn_model_features = tf.keras.Model(inputs=model_CNN.input, outputs=cnn_layer_output)
cnn_model_features = tf.keras.Model(inputs=model_CNN.input, outputs=model_CNN.layers[-3].output)

# %% [markdown]
# ## Extracting Features from CNN Model

# %%
# Extract features from input data using the CNN model
X_train_cnn = cnn_model_features.predict(Data)
X_test_cnn = cnn_model_features.predict(X_test)
# Out:
# 1177/1177 [==============================] - 3s 2ms/step
# 63/63 [==============================] - 0s 4ms/step

# %% [markdown]
# ## Integrating CNN with SVM Classifier using Grid Search for Best Perameters

# %%
import numpy as np
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

clf=SVC(kernel='rbf',C=100,gamma=0.001)
kf=KFold(n_splits=5)
scores_SVM = cross_val_score(clf, X_train_cnn, Label, cv=kf)
print(scores_SVM)
print("%0.2f accuracy with a standard deviation of %0.2f" % (scores_SVM.mean(), scores_SVM.std()))
clf.fit(X_train_cnn, Label)
# Evaluate the combined CNN-SVM model on a test dataset
svm_accuracy = clf.score(X_test_cnn, Y_test)
print('SVM Accuracy:', svm_accuracy*100)
y_testSVM = clf.predict(X_test_cnn)
# Out:
# [1. 1. 1. 1. 1.]
# 1.00 accuracy with a standard deviation of 0.00
# SVM Accuracy: 76.53519720419371

# %%
svm_accuracy = clf.score(X_test_cnn, Y_test)
print('SVM Accuracy:', svm_accuracy*100)
# Out:
# SVM Accuracy: 76.53519720419371

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

print(classification_report(Y_test, y_testSVM,target_names=target_names))
print("Accuracy: {0}".format(accuracy_score(Y_test, y_testSVM)*100))
# Out:
#                                                   precision    recall  f1-score   support
#
# Actinic keratoses and intraepithelial carcinomae       0.40      0.30      0.34        61
#                             basal cell carcinoma       0.55      0.50      0.52        96
#                    benign keratosis-like lesions       0.57      0.44      0.50       228
#                                   dermatofibroma       0.86      0.32      0.47        37
#                                 melanocytic nevi       0.85      0.93      0.89      1327
#               pyogenic granulomas and hemorrhage       1.00      0.50      0.67        32
#                                         melanoma       0.49      0.47      0.48       222
#
#                                         accuracy                           0.77      2003
#                                        macro avg       0.67      0.49      0.55      2003
#                                     weighted avg       0.75      0.77      0.75      2003
#
# Accuracy: 76.53519720419371

# %% [markdown]
# ## Integrating CNN with Random Forest Classifier using Grid Search for Best Perameters

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
rgclf = RandomForestClassifier(max_depth=3,
               max_features=1,
               min_samples_split=3,
               bootstrap=False,
               criterion=  "entropy",
               n_estimators=20)
kf=KFold(n_splits=5)
scores_RF = cross_val_score(rgclf, X_train_cnn, Label, cv=kf)
print(scores_RF)
print("%0.2f accuracy with a standard deviation of %0.2f" % (scores_RF.mean(), scores_RF.std()))
rgclf.fit(X_train_cnn, Label)
RFC_accuracy = rgclf.score(X_test_cnn, Y_test)
print('Random Forest Classifier Accuracy:', RFC_accuracy*100)
y_test_RF = rgclf.predict(X_test_cnn)
print("Accuracy: {0}".format(accuracy_score(Y_test, y_test_RF)*100))
# Out:
# [0.32749004 0.32846328 0.78934785 0.29605525 0.42024173]
# 0.43 accuracy with a standard deviation of 0.18
# Random Forest Classifier Accuracy: 72.44133799301048
# Accuracy: 72.44133799301048

# %%
y_test_RF = rgclf.predict(X_test_cnn)
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

print(classification_report(Y_test, y_test_RF,target_names=target_names))
print("Accuracy Score: {0}".format(accuracy_score(Y_test, y_test_RF)*100))
# Out:
#                                                   precision    recall  f1-score   support
#
# Actinic keratoses and intraepithelial carcinomae       1.00      1.00      1.00      1359
#                             basal cell carcinoma       0.99      1.00      0.99      1318
#                    benign keratosis-like lesions       0.94      0.98      0.96      1262
#                                   dermatofibroma       1.00      1.00      1.00      1351
#                                 melanocytic nevi       0.98      0.87      0.93      1374
#               pyogenic granulomas and hemorrhage       1.00      1.00      1.00      1358
#                                         melanoma       0.93      0.98      0.95      1365
#
#                                         accuracy                           0.98      9387
#                                        macro avg       0.98      0.98      0.98      9387
#                                     weighted avg       0.98      0.98      0.98      9387
#
# Accuracy Score: 97.57110898050495

# %%
y_test_RF = rgclf.predict(X_test_cnn)
print("Accuracy: {0}".format(accuracy_score(Y_test, y_test_RF)*100))
# Out:
# Accuracy: 97.57110898050495

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

# parameters = {"n_neighbors": [1],
#               "weights": ['uniform', 'distance'],
#               "metric": ['minkowski','euclidean','manhattan'],
#               "algorithm": ['auto', 'ball_tree', 'kd_tree', 'brute']}
kgclf = KNeighborsClassifier(n_neighbors=1,
              weights='distance',
              metric='euclidean',
              algorithm= 'auto')
kf=KFold(n_splits=5)
scores_KNN = cross_val_score(kgclf, X_train_cnn, Y_train, cv=kf)
print(scores_KNN)
print("%0.2f accuracy with a standard deviation of %0.2f" % (scores_KNN.mean(), scores_KNN.std()))
kgclf.fit(X_train_cnn, Y_train)
KNN_accuracy = kgclf.score(X_test_cnn, Y_test)
print('KNN Classifier Accuracy:', KNN_accuracy*100)
# Out:
# [0.99960053 0.99946738 0.99986684 0.99986683 0.98042349]
# 1.00 accuracy with a standard deviation of 0.01
# KNN Classifier Accuracy: 98.8281666134015

# %%
y_testKNN = kgclf.predict(X_test_cnn)
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

print(classification_report(Y_test, y_testKNN,target_names=target_names))
print("Accuracy Score: {0}".format(accuracy_score(Y_test, y_testKNN)*100))
# Out:
#                                                   precision    recall  f1-score   support
#
# Actinic keratoses and intraepithelial carcinomae       1.00      1.00      1.00      1359
#                             basal cell carcinoma       1.00      1.00      1.00      1318
#                    benign keratosis-like lesions       0.96      1.00      0.98      1262
#                                   dermatofibroma       1.00      1.00      1.00      1351
#                                 melanocytic nevi       1.00      0.92      0.96      1374
#               pyogenic granulomas and hemorrhage       1.00      1.00      1.00      1358
#                                         melanoma       0.96      1.00      0.98      1365
#
#                                         accuracy                           0.99      9387
#                                        macro avg       0.99      0.99      0.99      9387
#                                     weighted avg       0.99      0.99      0.99      9387
#
# Accuracy Score: 98.8281666134015

# %% [markdown]
# ## Integrating CNN with Logistic Regression Classifier using Grid Search for Best Perameters

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score



# Create a logistic regression object
grid_search_LR = LogisticRegression(C=100,
              penalty='l2')
kf=KFold(n_splits=5)
scores_LR = cross_val_score(grid_search_LR, X_train_cnn, Y_train, cv=kf)
print(scores_LR)
print("%0.2f accuracy with a standard deviation of %0.2f" % (scores_LR.mean(), scores_LR.std()))
# Perform grid search with 5-fold cross-validation
grid_search_LR.fit(X_train_cnn, Y_train)

# Print the best hyperparameters and the corresponding accuracy score
y_test_LR = grid_search_LR.predict(X_test_cnn)

print(classification_report(Y_test, y_test_LR,target_names=target_names))
print("Accuracy: {0}".format(accuracy_score(Y_test, y_test_LR)*100))
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# [1.         0.99986684 1.         0.99986683 0.97975762]
# 1.00 accuracy with a standard deviation of 0.01
#                                                   precision    recall  f1-score   support
#
# Actinic keratoses and intraepithelial carcinomae       1.00      1.00      1.00      1359
#                             basal cell carcinoma       1.00      1.00      1.00      1318
#                    benign keratosis-like lesions       0.96      0.99      0.97      1262
#                                   dermatofibroma       1.00      1.00      1.00      1351
#                                 melanocytic nevi       0.99      0.92      0.95      1374
#               pyogenic granulomas and hemorrhage       1.00      1.00      1.00      1358
#                                         melanoma       0.95      0.98      0.97      1365
#
#                                         accuracy                           0.98      9387
#                                        macro avg       0.98      0.98      0.98      9387
#                                     weighted avg       0.98      0.98      0.98      9387
#
# Accuracy: 98.42335144348567
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,

# %%
X_test.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_23/4158156979.py in <module>
# ----> 1 X_test.head()
#
# NameError: name 'X_test' is not defined
