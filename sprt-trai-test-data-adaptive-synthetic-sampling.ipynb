# %% [markdown]
# ## Dataset Overview
# HAM10000 ("Human Against Machine with 10000 training images") dataset - a large collection of multi-source dermatoscopic images of pigmented lesions
#
# The dermatoscopic images are collected from different populations, acquired and stored by different modalities. The final dataset consists of 10015 dermatoscopic images.
#
# It has 7 different classes of skin cancer which are listed below :
# - Melanocytic nevi
# - Melanoma
# - Benign keratosis-like lesions
# - Basal cell carcinoma
# - Actinic keratoses
# - Vascular lesions
# - Dermatofibroma

# %% [markdown]
# ## Importing libraries

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from imblearn.over_sampling import RandomOverSampler 
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score,KFold

import os, cv2
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPool2D, Activation, BatchNormalization
from sklearn.metrics import classification_report, accuracy_score

# %% [markdown]
# ## Reading the Data

# %%
data = pd.read_csv('/kaggle/input/skin-cancer-mnist-ham10000/hmnist_28_28_RGB.csv')
data.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 0        197        154        185        202  ...        173        124
# 1        123         93        126        158  ...         60         39
# 2        201        142        160        206  ...        167        129
# 3        143        103        119        171  ...         44         26
# 4        215        162        191        225  ...        209        166
#
#    pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# 0        138        183        147        166        185        154
# 1         55         25         14         28         25         14
# 2        143        159        124        142        136        104
# 3         36         25         12         17         25         12
# 4        185        172        135        149        109         78
#
#    pixel2351  label
# 0        177      2
# 1         27      2
# 2        117      2
# 3         15      2
# 4         92      2
#
# [5 rows x 2353 columns]

# %%
f , ax = plt.subplots(2,5)
f.set_size_inches(15, 15)
k = 0
y1 = data['label']
x1 = data.drop(columns = ['label'])
x1= np.array(x1).reshape(-1,28,28,3)
for i in range(2):
    for j in range(5):
        ax[i,j].imshow(x1[k].reshape(28,28,3))
#         ax[i, j].set_title(f"Image {Y_train[4]}")
        k = k + 1
    plt.tight_layout()

# %% [markdown]
# ## Data Preprocessing
# ## Data Cleaning

# %%
data['label'].unique()
y = data['label']
x = data.drop(columns = ['label'])
data.isnull().sum().sum() #no null values present
# Out:
# 0

# %%
meta_data = pd.read_csv('/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_metadata.csv')
meta_data.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
meta_data['dx'].unique()
# Out:
# array(['bkl', 'nv', 'df', 'mel', 'vasc', 'bcc', 'akiec'], dtype=object)

# %%
data.isnull().sum().sum() #no null values present
meta_data.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %% [markdown]
# ## Exploratory Data Analysis

# %%
sns.countplot(x = 'dx', data = meta_data)
plt.xlabel('Disease(Classes)', size=12)
plt.ylabel('Frequency', size=12)
plt.title('Frequency Distribution of Classes')
# Out:
# Text(0.5, 1.0, 'Frequency Distribution of Classes')

# %%
sns.set_style('whitegrid')
colors = ['#87ace8','#e3784d', 'green']
fig,axes = plt.subplots(figsize=(8,8))

ax = sns.countplot(x='sex',data=meta_data, palette = 'Paired')
for container in ax.containers:
    ax.bar_label(container)
plt.title('Gender-wise Distribution',fontweight='bold', fontsize=12)
plt.xticks(rotation=45)
plt.xticks(fontweight='bold', fontsize=12)
plt.yticks(fontweight='bold', fontsize=12)
plt.show()

# %%
sns.set_style('whitegrid')
fig,axes = plt.subplots(figsize=(8,6))
ax = sns.countplot(x='dx',data=meta_data, order = meta_data['dx'].value_counts().index, palette = 'Paired')
for container in ax.containers:
    ax.bar_label(container)
plt.title('Skin Disease class distribution',fontweight='bold',fontsize=14)
plt.xticks(rotation=45)
plt.ylim(0, 8000)
plt.xticks(fontweight='bold', fontsize=12)
plt.yticks(fontweight='bold', fontsize=12)
plt.ylabel("Count",fontweight='bold', fontsize=14)
plt.xlabel("Disease Class", fontweight='bold', fontsize=14)
plt.show()

# %%
classes = {2:'bkl', 4:'nv', 3:'df', 6:'mel', 5:'vasc', 1:'bcc', 0:'akiec'}

classes_labels=[]
for key in classes.keys():
    classes_labels.append(key)
print(classes_labels)
# Out:
# [2, 4, 3, 6, 5, 1, 0]

# %%
sns.set_style('whitegrid')
fig,axes = plt.subplots(figsize=(12,8))
ax = sns.countplot(x='dx',hue='sex', data=meta_data, order = meta_data['dx'].value_counts().index, palette = 'Paired')
for container in ax.containers:
    ax.bar_label(container)
plt.title('Cell Types Frequencies',fontweight='bold', fontsize=14)
plt.xticks(rotation=45)
plt.xticks(fontweight='bold', fontsize=12)
plt.yticks(fontweight='bold', fontsize=12)
plt.ylabel("Count",fontweight='bold', fontsize=14)
plt.xlabel("Gender Wise Disease Class", fontweight='bold', fontsize=14)
plt.show()

# %%
sns.set_style('whitegrid')
fig,axes = plt.subplots(figsize=(12,8))
ax = sns.countplot(x='localization',data=meta_data, order = meta_data['localization'].value_counts().index, palette = 'crest')
for container in ax.containers:
    ax.bar_label(container)
plt.title('Localization Area Frequencies',fontweight='bold', fontsize=14)
plt.xticks(rotation=45)
plt.xticks(fontweight='bold', fontsize=12)
plt.yticks(fontweight='bold', fontsize=12)
plt.ylabel("Count",fontweight='bold', fontsize=14)
plt.xlabel("localization", fontweight='bold', fontsize=14)
plt.show()

# %%
sns.set_style('whitegrid')
fig,axes = plt.subplots(figsize=(12,8))
ax = sns.histplot(data=meta_data, x='age')
plt.title('Age Histogram',fontweight='bold', fontsize=14)
plt.xticks(fontweight='bold', fontsize=12)
plt.yticks(fontweight='bold', fontsize=12)
plt.ylabel("Count",fontweight='bold', fontsize=14)
plt.xlabel("Age", fontweight='bold', fontsize=14)
plt.show()

# %%
sns.set_style('whitegrid')
fig,axes = plt.subplots(figsize=(12,8))
ax = sns.histplot(data=meta_data, x='age',hue='sex',multiple='stack')
plt.title('Age Histogram Gender Wise',fontweight='bold', fontsize=14)
plt.xticks(fontweight='bold', fontsize=12)
plt.yticks(fontweight='bold', fontsize=12)
plt.ylabel("Count",fontweight='bold', fontsize=14)
plt.xlabel("Age", fontweight='bold', fontsize=14)
plt.show()

# %%
print(x.shape,y.shape)
# Out:
# (10015, 2352) (10015,)

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)
print(X_train.shape,y_train.shape)
print(X_test.shape,y_test.shape)
# Out:
# (8012, 2352) (8012,)
# (2003, 2352) (2003,)

# %%
import numpy as np
from imblearn.over_sampling import ADASYN

# Assuming you have your feature data 'X' and corresponding labels 'y'
# X: numpy array of shape (n_samples, n_features)
# y: numpy array of shape (n_samples,)

# Instantiate the ADASYN oversampler
adasyn = ADASYN(random_state=42)

# Resample the data using ADASYN
X_test, y_test = adasyn.fit_resample(X_test, y_test)

X_train, y_train = adasyn.fit_resample(X_train, y_train)

# Check the class distribution after resampling
unique, counts = np.unique(y_train, return_counts=True)
print(dict(zip(unique, counts)))
unique, counts = np.unique(y_test, return_counts=True)
print(dict(zip(unique, counts)))
# Out:
# {0: 5326, 1: 5375, 2: 5516, 3: 5348, 4: 5367, 5: 5376, 6: 5431}
# {0: 1351, 1: 1354, 2: 1319, 3: 1342, 4: 1338, 5: 1347, 6: 1396}

# %%
print(x.shape)
print(y.shape)
print(X_train.shape,y_train.shape)
print(X_test.shape,y_test.shape)
# Out:
# (10015, 2352)
# (10015,)
# (37739, 2352) (37739,)
# (9447, 2352) (9447,)

# %%
# Split the dataset into training and testing sets
# Split the dataset into training and testing sets

# %%
# Out:
# (8012, 2352) (8012,)
# (2003, 2352) (2003,)

# %%
# reshaping the data so that it can be taken by convolution neural network(without disturbing the no. of samples)
X_train= np.array(X_train).reshape(-1,28,28,3)
print('Shape of X :',X_train.shape)
print('Shape of y :',y_train.shape)
# Out:
# Shape of X : (37739, 28, 28, 3)
# Shape of y : (37739,)

# %%
print(y_train)
# Out:
# 0        4
# 1        4
# 2        4
# 3        2
# 4        2
#         ..
# 37734    6
# 37735    6
# 37736    6
# 37737    6
# 37738    6
# Name: label, Length: 37739, dtype: int64

# %%
newLabel = []

for i in range(len(y_train)):
    for key in classes.keys():
        if y_train[i] == key:
            newLabel.append(classes[key])

# %%
classes = {4:'melanocytic nevi',
6: 'melanoma',
2:'benign keratosis-like lesions',
1:'basal cell carcinoma',
5:'pyogenic granulomas and hemorrhage',
0:'Actinic keratoses and intraepithelial carcinomae',
3:'dermatofibroma'}

# %%
y_train[:10]
# Out:
# 0    4
# 1    4
# 2    4
# 3    2
# 4    2
# 5    4
# 6    4
# 7    2
# 8    0
# 9    4
# Name: label, dtype: int64

# %%
l_train = np.array(y_train)
l_train[1]
# Out:
# 4

# %%
model_CNN = Sequential()
model_CNN.add(Conv2D(32, kernel_size = (3,3), input_shape = (28, 28, 3), activation = 'relu', padding = 'same'))
model_CNN.add(BatchNormalization())


model_CNN.add(MaxPool2D(pool_size = (2,2)))


model_CNN.add(Conv2D(64, kernel_size = (3,3), activation = 'relu', padding = 'same'))
model_CNN.add(BatchNormalization())

model_CNN.add(MaxPool2D(pool_size = (2,2), padding = 'same'))
model_CNN.add(Conv2D(128, kernel_size = (3,3), activation = 'relu', padding = 'same'))
model_CNN.add(BatchNormalization())

model_CNN.add(MaxPool2D(pool_size = (2,2), padding = 'same'))

model_CNN.add(Flatten())


model_CNN.add(Dense(64, activation = 'relu'))
model_CNN.add(BatchNormalization())


model_CNN.add(Dense(32))
model_CNN.add(Activation(activation='relu'))
model_CNN.add(BatchNormalization())

model_CNN.add(Dense(16))
model_CNN.add(Activation(activation='relu'))
model_CNN.add(BatchNormalization())

model_CNN.add(Dense(7))
model_CNN.add(Activation(activation='softmax'))

optimizer = tf.keras.optimizers.Adam(learning_rate = 0.001)

model_CNN.compile(loss = 'sparse_categorical_crossentropy',
                 optimizer = optimizer,
                  metrics = ['accuracy'])
print(model_CNN.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 28, 28, 32)        896
#
#  batch_normalization_18 (Bat  (None, 28, 28, 32)       128
#  chNormalization)
#
#  max_pooling2d_9 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 14, 14, 64)        18496
#
#  batch_normalization_19 (Bat  (None, 14, 14, 64)       256
#  chNormalization)
#
#  max_pooling2d_10 (MaxPoolin  (None, 7, 7, 64)         0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 7, 7, 128)         73856
#
#  batch_normalization_20 (Bat  (None, 7, 7, 128)        512
#  chNormalization)
#
#  max_pooling2d_11 (MaxPoolin  (None, 4, 4, 128)        0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 2048)              0
#
#  dense_12 (Dense)            (None, 64)                131136
#
#  batch_normalization_21 (Bat  (None, 64)               256
#  chNormalization)
#
#  dense_13 (Dense)            (None, 32)                2080
#
#  activation_9 (Activation)   (None, 32)                0
#
#  batch_normalization_22 (Bat  (None, 32)               128
#  chNormalization)
#
#  dense_14 (Dense)            (None, 16)                528
#
#  activation_10 (Activation)  (None, 16)                0
#
#  batch_normalization_23 (Bat  (None, 16)               64
#  chNormalization)
#
#  dense_15 (Dense)            (None, 7)                 119
#
#  activation_11 (Activation)  (None, 7)                 0
#
# =================================================================
# Total params: 228,455
# Trainable params: 227,783
# Non-trainable params: 672
# _________________________________________________________________
# None

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='auto')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=1, mode='auto')
history = model_CNN.fit(X_train,
                    y_train,
                    validation_split=0.2,
                    batch_size = 64,
                    epochs = 100,
                    callbacks=[reduce_lr,early_stop])
# Out:
# Epoch 1/100
# 472/472 [==============================] - 9s 10ms/step - loss: 0.7725 - accuracy: 0.7420 - val_loss: 1.3142 - val_accuracy: 0.4347 - lr: 0.0010
# Epoch 2/100
# 472/472 [==============================] - 4s 9ms/step - loss: 0.3335 - accuracy: 0.8906 - val_loss: 1.0761 - val_accuracy: 0.5032 - lr: 0.0010
# Epoch 3/100
# 472/472 [==============================] - 4s 9ms/step - loss: 0.2322 - accuracy: 0.9210 - val_loss: 1.7740 - val_accuracy: 0.3691 - lr: 0.0010
# Epoch 4/100
# 472/472 [==============================] - 4s 9ms/step - loss: 0.1660 - accuracy: 0.9428 - val_loss: 1.6953 - val_accuracy: 0.3837 - lr: 0.0010
# Epoch 5/100
# 472/472 [==============================] - ETA: 0s - loss: 0.1582 - accuracy: 0.9456
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 472/472 [==============================] - 4s 9ms/step - loss: 0.1582 - accuracy: 0.9456 - val_loss: 1.2990 - val_accuracy: 0.4641 - lr: 0.0010
# Epoch 6/100
# 472/472 [==============================] - 5s 11ms/step - loss: 0.0851 - accuracy: 0.9726 - val_loss: 0.8977 - val_accuracy: 0.6029 - lr: 1.0000e-04
# Epoch 7/100
# 472/472 [==============================] - 4s 9ms/step - loss: 0.0648 - accuracy: 0.9801 - val_loss: 0.8691 - val_accuracy: 0.6154 - lr: 1.0000e-04
# Epoch 8/100
# 472/472 [==============================] - 4s 9ms/step - loss: 0.0546 - accuracy: 0.9833 - val_loss: 0.8654 - val_accuracy: 0.6235 - lr: 1.0000e-04
# Epoch 9/100
# 472/472 [==============================] - 4s 9ms/step - loss: 0.0463 - accuracy: 0.9855 - val_loss: 0.7299 - val_accuracy: 0.6698 - lr: 1.0000e-04
# Epoch 10/100
# 472/472 [==============================] - 4s 9ms/step - loss: 0.0395 - accuracy: 0.9873 - val_loss: 0.7662 - val_accuracy: 0.6710 - lr: 1.0000e-04
# Epoch 11/100
# 472/472 [==============================] - 4s 8ms/step - loss: 0.0327 - accuracy: 0.9907 - val_loss: 0.5626 - val_accuracy: 0.7553 - lr: 1.0000e-04
# Epoch 12/100
# 472/472 [==============================] - 4s 8ms/step - loss: 0.0288 - accuracy: 0.9917 - val_loss: 0.7084 - val_accuracy: 0.6985 - lr: 1.0000e-04
# Epoch 13/100
# 472/472 [==============================] - 4s 8ms/step - loss: 0.0225 - accuracy: 0.9938 - val_loss: 0.5169 - val_accuracy: 0.7940 - lr: 1.0000e-04
# Epoch 14/100
# 472/472 [==============================] - 4s 9ms/step - loss: 0.0175 - accuracy: 0.9958 - val_loss: 0.8710 - val_accuracy: 0.6741 - lr: 1.0000e-04
# Epoch 15/100
# 472/472 [==============================] - 4s 9ms/step - loss: 0.0146 - accuracy: 0.9967 - val_loss: 0.5656 - val_accuracy: 0.7825 - lr: 1.0000e-04
# Epoch 16/100
# 472/472 [==============================] - 4s 8ms/step - loss: 0.0127 - accuracy: 0.9974 - val_loss: 0.4605 - val_accuracy: 0.8394 - lr: 1.0000e-04
# Epoch 17/100
# 472/472 [==============================] - 4s 9ms/step - loss: 0.0105 - accuracy: 0.9976 - val_loss: 0.9051 - val_accuracy: 0.6925 - lr: 1.0000e-04
# Epoch 18/100
# 472/472 [==============================] - 4s 9ms/step - loss: 0.0082 - accuracy: 0.9984 - val_loss: 0.5782 - val_accuracy: 0.8018 - lr: 1.0000e-04
# Epoch 19/100
# 472/472 [==============================] - 4s 9ms/step - loss: 0.0081 - accuracy: 0.9985 - val_loss: 0.3458 - val_accuracy: 0.8824 - lr: 1.0000e-04
# Epoch 20/100
# 472/472 [==============================] - 4s 9ms/step - loss: 0.0086 - accuracy: 0.9980 - val_loss: 0.3343 - val_accuracy: 0.8828 - lr: 1.0000e-04
# Epoch 21/100
# 472/472 [==============================] - 5s 10ms/step - loss: 0.0055 - accuracy: 0.9990 - val_loss: 0.4465 - val_accuracy: 0.8560 - lr: 1.0000e-04
# Epoch 22/100
# 472/472 [==============================] - 4s 9ms/step - loss: 0.0038 - accuracy: 0.9996 - val_loss: 0.4019 - val_accuracy: 0.8667 - lr: 1.0000e-04
# Epoch 23/100
# 469/472 [============================>.] - ETA: 0s - loss: 0.0045 - accuracy: 0.9991
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 472/472 [==============================] - 4s 9ms/step - loss: 0.0045 - accuracy: 0.9991 - val_loss: 0.4981 - val_accuracy: 0.8384 - lr: 1.0000e-04
# Epoch 24/100
# 472/472 [==============================] - 4s 9ms/step - loss: 0.0032 - accuracy: 0.9996 - val_loss: 0.2877 - val_accuracy: 0.9000 - lr: 1.0000e-05
# Epoch 25/100
# 472/472 [==============================] - 4s 9ms/step - loss: 0.0025 - accuracy: 0.9997 - val_loss: 0.3028 - val_accuracy: 0.8973 - lr: 1.0000e-05
# Epoch 26/100
# 472/472 [==============================] - 4s 9ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 0.2982 - val_accuracy: 0.8980 - lr: 1.0000e-05
# Epoch 27/100
# 469/472 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 0.9999
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 472/472 [==============================] - 4s 8ms/step - loss: 0.0019 - accuracy: 0.9999 - val_loss: 0.3122 - val_accuracy: 0.8935 - lr: 1.0000e-05
# Epoch 28/100
# 472/472 [==============================] - 4s 8ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3064 - val_accuracy: 0.8955 - lr: 1.0000e-06
# Epoch 29/100
# 472/472 [==============================] - 4s 9ms/step - loss: 0.0019 - accuracy: 0.9998 - val_loss: 0.3118 - val_accuracy: 0.8949 - lr: 1.0000e-06
# Epoch 30/100
# 467/472 [============================>.] - ETA: 0s - loss: 0.0020 - accuracy: 0.9998
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 472/472 [==============================] - 4s 9ms/step - loss: 0.0020 - accuracy: 0.9998 - val_loss: 0.3085 - val_accuracy: 0.8957 - lr: 1.0000e-06
# Epoch 31/100
# 472/472 [==============================] - 4s 9ms/step - loss: 0.0020 - accuracy: 0.9999 - val_loss: 0.3193 - val_accuracy: 0.8927 - lr: 1.0000e-07
# Epoch 32/100
# 472/472 [==============================] - 5s 10ms/step - loss: 0.0019 - accuracy: 0.9999 - val_loss: 0.3090 - val_accuracy: 0.8940 - lr: 1.0000e-07
# Epoch 33/100
# 466/472 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.9999
# Epoch 33: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 472/472 [==============================] - 4s 8ms/step - loss: 0.0018 - accuracy: 0.9999 - val_loss: 0.3160 - val_accuracy: 0.8928 - lr: 1.0000e-07
# Epoch 34/100
# 472/472 [==============================] - 4s 9ms/step - loss: 0.0017 - accuracy: 0.9999 - val_loss: 0.3001 - val_accuracy: 0.8976 - lr: 1.0000e-08
# Epoch 34: early stopping

# %%
X_test = np.array(X_test).reshape(-1,28,28,3)

# %%
results = model_CNN.evaluate(X_test , y_test, verbose=0)

print("CNN Model Test Results")
print("        Test Loss: {:.5f}".format(results[0]))
print("    Test Accuracy: {:.2f}%".format(results[1] * 100))
# Out:
# CNN Model Test Results
#         Test Loss: 1.54959
#     Test Accuracy: 50.37%

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %%
from sklearn.metrics import confusion_matrix , classification_report

y_true_CNN = list(y_resampled)
y_pred_CNN = model_CNN.predict(X_resampled)
y_pred_CNN = list(map(lambda x: np.argmax(x), y_pred_CNN))
print("Predicting First Ten Rows:")
print('Y Actual Values :' , y_true_CNN[0:10])
print('Y Predicted Values :' , y_pred_CNN[0:10])
# Out:
# 296/296 [==============================] - 1s 2ms/step
# Predicting First Ten Rows:
# Y Actual Values : [6, 4, 6, 2, 4, 4, 4, 4, 6, 4]
# Y Predicted Values : [2, 4, 0, 2, 6, 1, 2, 4, 2, 4]

# %%
cm_CNN = confusion_matrix(y_true_CNN,y_pred_CNN,labels=classes_labels)
print(confusion_matrix(y_true_CNN,y_pred_CNN,labels=classes_labels))
sns.heatmap(cm_CNN, annot = True, fmt='')
# Out:
# [[ 666  463    0  119    0   36   35]
#  [  36 1235    0   54    2   10    1]
#  [ 320  380  117    9   62  407   47]
#  [ 195  660    2  487    0   25   27]
#  [   4  227    2   40  982   88    4]
#  [ 156  178   17   62   13  845   83]
#  [ 237  216   13  131    0  328  426]]
# <Axes: >

# %%
#training acc vs testing acc graph
plt.plot(history.history["accuracy"] , 'ro-' , label = "Training Accuracy")
plt.plot(history.history["val_accuracy"] , 'go-' , label = "Testing Accuracy")
plt.legend()
plt.show()

# %%
#predicting
y_pred_CNN  = model_CNN.predict(X_resampled)
target_names = [f"{classes[i]}" for i in range(7)]
y_pred_CNN = list(map(lambda x: np.argmax(x), y_pred_CNN))
print("CNN Model Prediction Results")
print(classification_report(y_resampled , y_pred_CNN,target_names=target_names))
# Out:
# 296/296 [==============================] - 1s 2ms/step
# CNN Model Prediction Results
#                                                   precision    recall  f1-score   support
#
# Actinic keratoses and intraepithelial carcinomae       0.68      0.32      0.43      1351
#                             basal cell carcinoma       0.49      0.62      0.55      1354
#                    benign keratosis-like lesions       0.41      0.50      0.45      1319
#                                   dermatofibroma       0.77      0.09      0.16      1342
#                                 melanocytic nevi       0.37      0.92      0.53      1338
#               pyogenic granulomas and hemorrhage       0.93      0.73      0.82      1347
#                                         melanoma       0.54      0.35      0.42      1396
#
#                                         accuracy                           0.50      9447
#                                        macro avg       0.60      0.50      0.48      9447
#                                     weighted avg       0.60      0.50      0.48      9447
